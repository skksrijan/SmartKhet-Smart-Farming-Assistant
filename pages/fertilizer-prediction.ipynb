# %%
import pandas as pd
data=pd.read_csv('./Fertilizer Prediction.csv')
data
# Out:
#     Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38     Sandy      Maize        37
# 1            29         52        45     Loamy  Sugarcane        12
# 2            34         65        62     Black     Cotton         7
# 3            32         62        34       Red    Tobacco        22
# 4            28         54        46    Clayey      Paddy        35
# ..          ...        ...       ...       ...        ...       ...
# 94           25         50        32    Clayey     Pulses        24
# 95           30         60        27       Red    Tobacco         4
# 96           38         72        51     Loamy      Wheat        39
# 97           36         60        43     Sandy    Millets        15
# 98           29         58        57     Black  Sugarcane        12
#
#     Potassium  Phosphorous Fertilizer Name
# 0           0            0            Urea
# 1           0           36             DAP
# ...

# %%
data.iloc[:,-1]
# Out:
# 0         Urea
# 1          DAP
# 2     14-35-14
# 3        28-28
# 4         Urea
#         ...
# 94       28-28
# 95    10-26-26
# 96        Urea
# 97         DAP
# 98       20-20
# Name: Fertilizer Name, Length: 99, dtype: object

# %%
soil_type=data['Soil Type'].unique()

# %%
soil_type
# Out:
# array(['Sandy', 'Loamy', 'Black', 'Red', 'Clayey'], dtype=object)

# %%
soil_dic={}
j=0
for i in soil_type:
    soil_dic.update({i:j})
    j+=1
soil_dic
# Out:
# {'Sandy': 0, 'Loamy': 1, 'Black': 2, 'Red': 3, 'Clayey': 4}

# %%
data['Soil Type']=data['Soil Type'].replace(soil_dic)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15120\919608752.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Soil Type']=data['Soil Type'].replace(soil_dic)

# %%
data
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          0      Maize        37
# 1            29         52        45          1  Sugarcane        12
# 2            34         65        62          2     Cotton         7
# 3            32         62        34          3    Tobacco        22
# 4            28         54        46          4      Paddy        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          4     Pulses        24
# 95           30         60        27          3    Tobacco         4
# 96           38         72        51          1      Wheat        39
# 97           36         60        43          0    Millets        15
# 98           29         58        57          2  Sugarcane        12
#
#     Potassium  Phosphorous Fertilizer Name
# 0           0            0            Urea
# 1           0           36             DAP
# ...

# %%
crop_type=data['Crop Type'].unique()

# %%
crop_type
# Out:
# array(['Maize', 'Sugarcane', 'Cotton', 'Tobacco', 'Paddy', 'Barley',
#        'Wheat', 'Millets', 'Oil seeds', 'Pulses', 'Ground Nuts'],
#       dtype=object)

# %%
crop_dic={}
i=0;
for j in crop_type:
    crop_dic.update({j:i})
    i+=1

# %%
crop_dic
# Out:
# {'Maize': 0,
#  'Sugarcane': 1,
#  'Cotton': 2,
#  'Tobacco': 3,
#  'Paddy': 4,
#  'Barley': 5,
#  'Wheat': 6,
#  'Millets': 7,
#  'Oil seeds': 8,
#  'Pulses': 9,
#  'Ground Nuts': 10}

# %%
data['Crop Type']=data['Crop Type'].replace(crop_dic)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15120\3750574311.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Crop Type']=data['Crop Type'].replace(crop_dic)

# %%
data
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          0          0        37
# 1            29         52        45          1          1        12
# 2            34         65        62          2          2         7
# 3            32         62        34          3          3        22
# 4            28         54        46          4          4        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          4          9        24
# 95           30         60        27          3          3         4
# 96           38         72        51          1          6        39
# 97           36         60        43          0          7        15
# 98           29         58        57          2          1        12
#
#     Potassium  Phosphorous Fertilizer Name
# 0           0            0            Urea
# 1           0           36             DAP
# ...

# %%
fertilizer_type=data['Fertilizer Name'].unique()

# %%
i=0
fer_dic={}
for j in fertilizer_type:
    fer_dic.update({j:i})
    i+=1
fer_dic
# Out:
# {'Urea': 0,
#  'DAP': 1,
#  '14-35-14': 2,
#  '28-28': 3,
#  '17-17-17': 4,
#  '20-20': 5,
#  '10-26-26': 6}

# %%
data['Fertilizer Name']=data['Fertilizer Name'].replace(fer_dic)
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_15120\942085735.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Fertilizer Name']=data['Fertilizer Name'].replace(fer_dic)

# %%
data
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          0          0        37
# 1            29         52        45          1          1        12
# 2            34         65        62          2          2         7
# 3            32         62        34          3          3        22
# 4            28         54        46          4          4        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          4          9        24
# 95           30         60        27          3          3         4
# 96           38         72        51          1          6        39
# 97           36         60        43          0          7        15
# 98           29         58        57          2          1        12
#
#     Potassium  Phosphorous  Fertilizer Name
# 0           0            0                0
# 1           0           36                1
# ...

# %%
data.corr()
# Out:
#                  Temparature  Humidity   Moisture  Soil Type  Crop Type  \
# Temparature         1.000000   0.973164  0.091222  -0.023322  -0.074528
# Humidity            0.973164   1.000000  0.091342  -0.024092  -0.090625
# Moisture            0.091222   0.091342  1.000000  -0.227293  -0.555514
# Soil Type          -0.023322  -0.024092 -0.227293   1.000000   0.306314
# Crop Type          -0.074528  -0.090625 -0.555514   0.306314   1.000000
# Nitrogen           -0.033771  -0.060646 -0.095945   0.093496   0.162689
# Potassium          -0.023424  -0.003833  0.027727   0.016914  -0.141970
# Phosphorous         0.207545   0.204044  0.009276  -0.061374  -0.054373
# Fertilizer Name    -0.179102  -0.138612  0.036122   0.002882  -0.055463
#
#                  Nitrogen  Potassium  Phosphorous  Fertilizer Name
# Temparature     -0.033771  -0.023424     0.207545        -0.179102
# Humidity        -0.060646  -0.003833     0.204044        -0.138612
# ...

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          0          0        37
# 1            29         52        45          1          1        12
# 2            34         65        62          2          2         7
# 3            32         62        34          3          3        22
# 4            28         54        46          4          4        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          4          9        24
# 95           30         60        27          3          3         4
# 96           38         72        51          1          6        39
# 97           36         60        43          0          7        15
# 98           29         58        57          2          1        12
#
#     Potassium  Phosphorous  Fertilizer Name
# 0           0            0                0
# 1           0           36                1
# ...

# %%
from sklearn.preprocessing import StandardScaler
x=StandardScaler().fit_transform(data.drop(columns='Fertilizer Name'))
y=data['Fertilizer Name']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import BernoulliNB
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
import optuna

def train(trial, x_train, y_train):
    algo_name = trial.suggest_categorical('classifier', ['lr', 'dt', 'rf', 'svc', 'knn', 'br', 'gb', 'xgb'])

    if algo_name == 'lr':
        model = LogisticRegression(
            # penalty=trial.suggest_categorical('penalty', ['l1', 'l2', 'none']),
            C=trial.suggest_float('C', 1e-4, 1e2, log=True),
            solver=trial.suggest_categorical('solver', ['lbfgs', 'saga', 'liblinear']),
            max_iter=trial.suggest_int('max_iter', 100, 1000),
            class_weight='balanced'
        )

    elif algo_name == 'dt':
        model = DecisionTreeClassifier(
            criterion=trial.suggest_categorical('criterion', ['gini', 'entropy']),
            max_depth=trial.suggest_int('max_depth', 1, 50),
            min_samples_split=trial.suggest_int('min_samples_split', 2, 20),
            min_samples_leaf=trial.suggest_int('min_samples_leaf', 1, 20),
            random_state=42
        )

    elif algo_name == 'rf':
        model = RandomForestClassifier(
            n_estimators=trial.suggest_int('n_estimators', 10, 500),
            max_depth=trial.suggest_int('max_depth', 1, 50),
            min_samples_split=trial.suggest_int('min_samples_split', 2, 20),
            min_samples_leaf=trial.suggest_int('min_samples_leaf', 1, 20),
            max_features=trial.suggest_categorical('max_features', [None, 'sqrt', 'log2']),
            bootstrap=True,
            random_state=42
        )

    elif algo_name == 'svc':
        model = SVC(
            C=trial.suggest_float('C', 1e-4, 1e2, log=True),
            kernel=trial.suggest_categorical('kernel', ['linear', 'poly', 'rbf', 'sigmoid']),
            gamma=trial.suggest_categorical('gamma', ['scale', 'auto']),
            probability=True
        )

    elif algo_name == 'knn':
        model = KNeighborsClassifier(
            n_neighbors=trial.suggest_int('n_neighbors', 1, 50),
            weights=trial.suggest_categorical('weights', ['uniform', 'distance']),
            metric=trial.suggest_categorical('metric', ['euclidean', 'manhattan', 'minkowski'])
        )

    elif algo_name == 'br':
        model = BernoulliNB(
            alpha=trial.suggest_float('alpha', 1e-4, 1e1, log=True),
            binarize=trial.suggest_float('binarize', 1e-4, 1.0)
        )

    elif algo_name == 'gb':
        model = GradientBoostingClassifier(
            n_estimators=trial.suggest_int('n_estimators', 10, 500),
            learning_rate=trial.suggest_float('learning_rate', 1e-4, 1e0, log=True),
            max_depth=trial.suggest_int('max_depth', 1, 50),
            subsample=trial.suggest_float('subsample', 0.5, 1.0),
            random_state=42
        )

    elif algo_name == 'xgb':
        model = XGBClassifier(
            n_estimators=trial.suggest_int('n_estimators', 10, 500),
            max_depth=trial.suggest_int('max_depth', 1, 50),
            learning_rate=trial.suggest_float('learning_rate', 1e-4, 1e0, log=True),
            subsample=trial.suggest_float('subsample', 0.5, 1.0),
            colsample_bytree=trial.suggest_float('colsample_bytree', 0.5, 1.0),
            objective='binary:logistic',
            eval_metric='logloss',
            random_state=42
        )

    return cross_val_score(model, x_train, y_train, cv=5, scoring='accuracy', error_score='raise').mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(lambda trial: train(trial, x_train, y_train), n_trials=20, n_jobs=-1)
# Out:
# [I 2025-04-06 15:30:03,382] A new study created in memory with name: no-name-a0380021-08b4-49e1-84cf-b1ec76b6134a
# [I 2025-04-06 15:30:03,489] Trial 1 finished with value: 0.9241666666666667 and parameters: {'classifier': 'dt', 'criterion': 'gini', 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.9241666666666667.
# [I 2025-04-06 15:30:03,707] Trial 4 finished with value: 0.6825 and parameters: {'classifier': 'knn', 'n_neighbors': 43, 'weights': 'distance', 'metric': 'minkowski'}. Best is trial 1 with value: 0.9241666666666667.
# [I 2025-04-06 15:30:03,774] Trial 5 finished with value: 0.8741666666666668 and parameters: {'classifier': 'svc', 'C': 6.809186822415164, 'kernel': 'sigmoid', 'gamma': 'auto'}. Best is trial 1 with value: 0.9241666666666667.
# ...

# %%
study.best_params
# Out:
# {'classifier': 'gb',
#  'n_estimators': 180,
#  'learning_rate': 0.0026254070766278358,
#  'max_depth': 17,
#  'subsample': 0.7106681427751008}

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# Assuming your features and target are:
# X = your feature dataframe (e.g., df.drop('Fertilizer Name', axis=1))
# y = your target column (e.g., df['Fertilizer Name'])

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create the Gradient Boosting Classifier with given parameters
gb_model = GradientBoostingClassifier(
    n_estimators=180,
    learning_rate=0.0026254070766278358,
    max_depth=17,
    subsample=0.7106681427751008,
    random_state=42
)

# Train the model
gb_model.fit(X_train, y_train)

# Make predictions
y_pred = gb_model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         5
#            2       1.00      1.00      1.00         1
#            3       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         2
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
gb_model.predict(x_test)[0]
# Out:
# 3

# %%
i=0
fer_dic={}
for j in fertilizer_type:
    fer_dic.update({i:j})
    i+=1
fer_dic
# Out:
# {0: 'Urea',
#  1: 'DAP',
#  2: '14-35-14',
#  3: '28-28',
#  4: '17-17-17',
#  5: '20-20',
#  6: '10-26-26'}

# %%
fer_dic[gb_model.predict(x_test)[0]]
# Out:
# '28-28'

# %%
import joblib

joblib.dump(gb_model, 'gb_model_compressed.pkl','wb')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 3
#       1 import joblib
# ----> 3 joblib.dump(gb_model, 'gb_model_compressed.pkl','wb')
#
# File ~\anaconda3\Lib\site-packages\joblib\numpy_pickle.py:511, in dump(value, filename, compress, protocol, cache_size)
#     505     raise ValueError(
#     506         'Non valid compress level given: "{}". Possible values are '
#     507         '{}.'.format(compress_level, list(range(10))))
#     509 if compress_method not in _COMPRESSORS:
#     510     # Raising an error if an unsupported compression method is given.
# --> 511     raise ValueError(
#     512         'Non valid compression method given: "{}". Possible values are '
#     513         '{}.'.format(compress_method, _COMPRESSORS))
#     515 if not is_filename and not is_fileobj:
#     516     # People keep inverting arguments, and the resulting error is
# ...
